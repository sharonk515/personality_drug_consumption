# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from helper import *

# %% [markdown]
# ## Data
#
# The [database](https://archive.ics.uci.edu/ml/datasets/Drug+consumption+%28quantified%29#) contains records for 1885 respondents. For each respondent, 12 attributes are known:
# - personality measurements -- NEO-FFI-R (neuroticism, extraversion, openness to experience, agreeableness, and conscientiousness), BIS-11 (impulsivity), and ImpSS (sensation seeking)
# - level of education
# - age
# - gender
# - country of residence
# - ethnicity.
#
# In addition, participants were questioned concerning their use of 18 legal and illegal drugs (alcohol, amphetamines, amyl nitrite, benzodiazepines, cannabis, chocolate, cocaine, caffeine, crack, ecstasy, heroin, ketamine, legal highs, LSD, methadone, mushrooms, nicotine and volatile substance abuse and one fictitious drug (Semeron) which was introduced to identify over-claimers.
#
# For each drug, they selected ‘Never Used’, ‘Used over a Decade Ago’, ‘Used in Last Decade’, ‘Used in Last Year’, ‘Used in Last Month’, ‘Used in Last Week’, and ‘Used in Last Day’.

# %%
drug = pd.read_csv('data/drug_consumption.data', header=None, index_col=0)

# %%
#rename columns
drug.columns = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity',
               'Nscore', 'Escore', 'Oscore', 'Ascore', 'Cscore',
               'Impulsive', 'SS', 'Alcohol', 'Amphet', 'Amyl', 'Benzos',
               'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy',
               'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
               'Nicotine', 'Semer', 'VSA']

# %%
# Convert standardized values into categories
category_converter(drug)

# %% [markdown]
# ### Ordinal quantification of Data
#
# Convert ordinal categorical columns into numerical values

# %%
drug = encoding(drug)

# %%
per = {'SS': 'Sensation-seeking',
       'Oscore': 'Openness to experience',
       'Cscore': 'Conscientiousness',
       'Impulsive': 'Impusivity',
       'Ascore': 'Agreeableness',
       'Escore': 'Extraversion',
       'Nscore': 'Neuroticism'}

personality_cols = []
for col in drug.columns[5:12]:
    drug.rename({col: per[col]}, axis=1, inplace=True)
    personality_cols.append(per[col])

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Personalities
#
# [NEO Five-Factor Inventory (NEO-FFI-R)](https://arxiv.org/pdf/1506.06297.pdf) 60-item inventory comprised of five personality domains or factors: N, E, O, A, and C with 12 items per domain.
#
# 1. **Neuroticism (N)**:
#     - long-term tendency to experience negative emotions such as nervousness, tension, anxiety and depression
#
#
# 2. **Extraversion (E)**:
#     - manifested in outgoing, warm, active, assertive, talkative, cheerful, and in search of stimulation characteristics
#
#
# 3. **Openness to experience (O)**:
#     - general appreciation for art, unusual ideas, and imaginative, creative, unconventional, and wide interests
#
#
# 4. **Agreeableness (A)**:
#     - dimension of interpersonal relations, characterized by altruism, trust, modesty, kindness, compassion and cooperativeness
#
#
# 5. **Conscientiousness (C)**:
#     - tendency to be organized and dependable, strong-willed, persistent, reliable, and efficient
#
#
# Barratt **Impulsiveness** Scale (BIS-11), a 30-item self-report questionnaire that measures the behavioral construct of impulsiveness, and comprises three subscales: motor impulsiveness, attentional impulsiveness, and non-planning. The ‘motor’ aspect reflects acting without thinking, the ‘attentional’ component poor concentration and thought intrusions, and the ‘non-planning’ a lack of consideration for consequences. The higher BIS-11 scores, the higher the impulsivity level.
#
#
# Impulsiveness **Sensation-Seeking** (ImpSS), combines the traits of impulsivity (Imp) and sensation-seeking (SS).

# %%
# distributions of each personality type
fig, ax = plt.subplots(3, 3, figsize=(15, 17))
for i, col in enumerate(personality_cols):
    sns.distplot(drug[col], ax=ax[i//3, i%3])
    ax[i//3, i % 3].set_title(f"Distribution of {col}")
fig.delaxes(ax[2, 1])
fig.delaxes(ax[2, 2]);

# %% [markdown]
# ### Drugs

# %%
# define drug columns
drug_cols = ['Alcohol', 'Amphet', 'Amyl', 'Benzos',
             'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy',
             'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
             'Nicotine', 'Semer', 'VSA']

# %%
# define each class
classes = ['Never Used', 'Used over a Decade Ago', 'Used in Last Decade',
           'Used in Last Year', 'Used in Last Month', 'Used in Last Week', 'Used in Last Day']

# count of the classes for each drug
fig, ax = plt.subplots(5, 4, figsize=(18, 20))
for i, drugs in enumerate(drug_cols):
    sns.countplot(drug[drugs], ax=ax[i//4, i%4])
    ax[i//4, i%4].set_title(f"Count of Each Class for {drugs}")
    ax[i//4, i%4].set_xticklabels(classes, rotation=20, ha='right')
fig.delaxes(ax[4, 3])
plt.tight_layout();

# %%
# define user and non-user for each drug
for col in drug_cols:
    drug[f"{col}_User"] = [0 if (x == 'CL0') | (x == 'CL1') else 1
                         for x in drug[col]]

# %%
# count of users and non-users for each drug
fig, ax = plt.subplots(5, 4, figsize=(18, 20))
for i, drugs in enumerate(drug_cols):
    sns.countplot(drug[f"{drugs}_User"], ax=ax[i//4, i%4])
    ax[i//4, i%4].set_title(f"Count of Users vs Non-users for {drugs}")
fig.delaxes(ax[4, 3])
plt.tight_layout();

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.offline as py
from plotly.graph_objs import Scatter, Layout
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff

country = ['UK', 'USA', 'Canada', 'Australia', 'Ireland', 'New Zealand']

data = [dict(
        type='choropleth',
        locations=country,
        locationmode='country names',
        z=(drug['Country'].value_counts().values),
        text=country,
        colorscale='portland',
        reversescale=True,
        )]
layout = dict(
    title='A Map About Population of Drug Addicted in Each Country',
    geo=dict(showframe=False, showcoastlines=True,
             projection=dict(type='Mercator'))
)
fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='world-map')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="1bbb025c-ef92-4dab-bb17-f6e79dd9ebfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1bbb025c-ef92-4dab-bb17-f6e79dd9ebfa")) {
#                     Plotly.newPlot(
#                         '1bbb025c-ef92-4dab-bb17-f6e79dd9ebfa',
#                         [{"colorscale": "portland", "locationmode": "country names", "locations": ["UK", "USA", "Canada", "Australia", "Ireland", "New Zealand"], "reversescale": true, "text": ["UK", "USA", "Canada", "Australia", "Ireland", "New Zealand"], "type": "choropleth", "z": [1044, 557, 118, 87, 54, 20, 5]}],
#                         {"geo": {"projection": {"type": "Mercator"}, "showcoastlines": true, "showframe": false}, "title": "A Map About Population of Drug Addicted in Each Country"},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1bbb025c-ef92-4dab-bb17-f6e79dd9ebfa');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### Correlation between personalities and drugs

# %%
corrmat = drug.corr()

plt.figure(figsize=(20, 20))
sns.set(font_scale=1)
hm = sns.heatmap(corrmat, cmap='RdYlGn', annot=True,
                 yticklabels=drug.columns, xticklabels=drug.columns)
plt.xticks(fontsize=13, rotation=50)
plt.yticks(fontsize=13)
plt.title("Correlation B/W Different Features", fontsize=18);

# %% [markdown]
# ## Cannabis and Ecstasy Data

# %% [markdown]
# ### Cannabis

# %%
# filter for just Cannabis Users
cannabis = drug[['Cannabis_User', 'Age', 'Gender', 'Education',
                 'Country', 'Ethnicity'] + personality_cols]

cannabis.rename({'Cannabis_User': 'User'}, axis=1, inplace=True)
cannabis.drop(columns=['Country', 'Ethnicity'], axis=1, inplace=True)

# save Cannabis DataFrame for future use
cannabis.to_csv('data/cannabis.csv', index=False)

# %% [markdown]
# ### Ecstasy

# %%
# filter for just Ecstasy Users
ecstasy = drug[['Ecstasy_User', 'Age', 'Gender', 'Education',
                 'Country', 'Ethnicity'] + personality_cols]

ecstasy.rename({'Ecstasy_User': 'User'}, axis=1, inplace=True)
ecstasy.drop(columns=['Country', 'Ethnicity'], axis=1, inplace=True)

# save Ecstasy DataFrame for future use
ecstasy.to_csv('data/ecstasy.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis of Cannabis and Ecstasy

# %%
cannabis = pd.read_csv('data/cannabis.csv')
ecstasy = pd.read_csv('data/ecstasy.csv')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
plt.subplots_adjust(wspace = 0.4)
sns.countplot(cannabis['User'], ax=ax[0])
sns.countplot(ecstasy['User'], ax=ax[1])
sns.despine(left=False, bottom=False)
for x in ax:
    x.set_xticklabels(labels=['Non-user', 'User'], fontsize=14)
    x.set_ylabel('count', fontsize=14)
    x.set_xlabel('')
ax[0].set_title('Number of Users vs Non-Users of Cannabis\n', fontsize=14)
ax[1].set_title('Number of Users vs Non-Users of Ecstasy\n', fontsize=14)
plt.savefig('img/users_vs_nonusers.png', bbox_inches='tight');

# %%
fig = plt.figure(figsize=(16, 20))
sns.set_palette(sns.light_palette((360, 90, 50), n_colors=7, input="husl"))

plt.suptitle(f'Cannabis consumption and personality scores', size=16)
for row, personality in enumerate(personality_cols):
    plt.subplot(4, 2, row+1)
    sns.boxplot(x=drug['Cannabis'], y=personality, data=drug,
                order=['CL0', 'CL1', 'CL2', 'CL3', 'CL4', 'CL5', 'CL6'])
    plt.xlabel(' ')

vc = drug['Cannabis'].value_counts()/len(drug)
plt.subplot(4, 2, 8)
sns.barplot(x=vc.index, y=vc)
plt.ylabel('Percent of the total');

# %%
sns.set_palette(sns.light_palette((220, 90, 60), n_colors=2, input="husl"))
sns.countplot(x="Age", hue="Cannabis_User", data=drug,
              order=['18-24', '25-34','35-44', '45-54', '55-64', '65+'],
             dodge=True);

# %%
sns.countplot(x="Education", hue="Cannabis_User", data=drug, orient='h')
plt.xticks(rotation=30, ha="right");

# %%
sns.countplot(x="Gender", hue="Cannabis_User", data=drug, orient='h');

# %%
sns.countplot(x="Ethnicity", hue="Cannabis_User", data=drug, orient='h')
plt.xticks(rotation=30, ha="right");

# %%
fig = plt.figure(figsize=(16, 20))
sns.set_palette(sns.light_palette((360, 90, 50), n_colors=7, input="husl"))

plt.suptitle(f'Ecstasy consumption and personality scores', size=16)
for row, personality in enumerate(personality_cols):
    plt.subplot(4, 2, row+1)
    sns.boxplot(x=drug['Ecstasy'], y=personality, data=drug,
                order=['CL0', 'CL1', 'CL2', 'CL3', 'CL4', 'CL5', 'CL6'])
    plt.xlabel(' ')

vc = drug['Ecstasy'].value_counts()/len(drug)
plt.subplot(4, 2, 8)
sns.barplot(x=vc.index, y=vc)
plt.ylabel('Percent of the total');

# %%
sns.set_palette(sns.light_palette((220, 90, 60), n_colors=2, input="husl"))
sns.countplot(x="Age", hue="Ecstasy_User", data=drug,
              order=['18-24', '25-34', '35-44', '45-54', '55-64', '65+'],
              dodge=True);

# %%
sns.countplot(x="Education", hue="Ecstasy_User", data=drug, orient='h')
plt.xticks(rotation=30, ha="right");

# %%
sns.countplot(x="Gender", hue="Ecstasy_User", data=drug, orient='h');

# %%
sns.countplot(x="Ethnicity", hue="Ecstasy_User", data=drug, orient='h')
plt.xticks(rotation=30, ha="right");
