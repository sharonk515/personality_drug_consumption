# %% [markdown]
# # Is there a relationship between a person's personality and nicotine consumption?
#
# According to the National Institute of Drug Abuse the drug usage related cost can reach or even exceed the annual $740 billion dollar in the USA: accidents from driving under the influence, crimes caused by or driven by drugs, healthcare cost, or when people dropout from potential workforce. The deaths caused by drug overdose is steadily increasing every year.
#
# Our purpose of the study is to identify the groups of people who are more likely to become users of a certain drug, so that we can reach them with preventive programs or targeted education that can keep them from becoming drug users.
#
# **[Nicotine](https://adf.org.au/drug-facts/nicotine/#wheel)**

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import pickle

import warnings
warnings.filterwarnings("ignore")

# libraries for cleaning and preprocessing data
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# libraries for modeling
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
import lightgbm as lgb

# libraries for evaluating models
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score

# libraries for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from helper import *
from visualizations import *
from modeling import *

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Reading Data

# %%
drugs = pd.read_csv('data/drug_consumption.data', header=None, index_col=0)

# %%
# rename columns
drugs.columns = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity',
                 'Neuroticism', 'Extraversion', 'Openness-to-experience',
                 'Agreeableness', 'Conscientiousness', 'Impulsive',
                 'Sensation-seeking', 'Alcohol', 'Amphet', 'Amyl', 'Benzos',
                 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy',
                 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
                 'Nicotine', 'Semer', 'VSA']

# %%
personality_cols = ['Neuroticism', 'Extraversion', 'Openness-to-experience',
                    'Agreeableness', 'Conscientiousness', 'Impulsive',
                    'Sensation-seeking']

# %%
# Convert standardized values into categories
category_converter(drugs)

# %%
# plot distribution of personalities for each class for nicotine
plot_personality(drugs, personality_cols, 'Nicotine')

# %%
# define drug columns
drug_cols = ['Alcohol', 'Amphet', 'Amyl', 'Benzos',
             'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy',
             'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
             'Nicotine', 'Semer', 'VSA']

# define user and non-user for each drug
for col in drug_cols:
    drugs[f"{col}_User"] = [0 if (x == 'CL0') | (x == 'CL1') else 1
                            for x in drugs[col]]

# %%
plot_feature_dist(drugs, 'Nicotine')

# %%
drugs = encoding(drugs)

# %%
# filter for just nicotine users
nicotine = drugs[['Nicotine_User', 'Age', 'Gender', 'Education',
             'Country', 'Ethnicity'] + personality_cols]

nicotine.rename({'Nicotine_User': 'User'}, axis=1, inplace=True)
nicotine.drop(columns=['Country', 'Ethnicity'], axis=1, inplace=True)

# save nicotine DataFrame for future use
nicotine.to_csv('data/nicotine.csv', index=False)

# %%
sns.reset_orig()

# %%
sns.countplot(nicotine['User'])
plt.title(f'Number of Users vs Non-Users of Nicotine \n',
          fontsize=14)
plt.xticks(np.arange(len(['Non-user', 'User'])),
           labels=['Non-user', 'User'],
           fontsize=14)
plt.ylabel('count', fontsize=14)
plt.xlabel('')
sns.despine(left=False, bottom=False)
plt.savefig('img/users_vs_nonusers - nicotine.png',
            bbox_inches='tight');

# %% [markdown]
# ## Preprocessing Data

# %%
nicotine = pd.read_csv('data/nicotine.csv')
nicotine.head()
# Out:
#    User  Age  Gender  Education  Neuroticism  Extraversion  \
# 0     1    2       0          5      0.31287      -0.57545
# 1     1    1       1          8     -0.67825       1.93886
# 2     0    2       1          5     -0.46725       0.80523
# 3     1    0       0          7     -0.14882      -0.80615
# 4     1    2       0          8      0.73545      -1.63340
#
#    Openness-to-experience  Agreeableness  Conscientiousness  Impulsive  \
# 0                -0.58331       -0.91699           -0.00665   -0.21712
# 1                 1.43533        0.76096           -0.14277   -0.71126
# 2                -0.84732       -1.62090           -1.01450   -1.37983
# 3                -0.01928        0.59042            0.58489   -1.37983
# 4                -0.45174       -0.30172            1.30612   -0.21712
#
#    Sensation-seeking
# 0           -1.18084
# 1           -0.21575
# 2            0.40148
# 3           -1.18084
# 4           -0.21575

# %% [markdown]
# ## Modeling

# %%
# define feature and target variables
y = nicotine['User']
X = nicotine.drop('User', axis=1)

sm = SMOTE(random_state=220)
X_sm, y_sm = sm.fit_resample(X, y)
X_sm = pd.DataFrame(X_sm, columns=X.columns)

# %%
# train-test split for modeling
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2,
                                                    random_state=220)

# %%
# scale data for Logistic Regression, KNN, and SVM
X_train_scale = X_train.copy()
X_test_scale = X_test.copy()

scale = StandardScaler()

X_train_scale.loc[:, ['Age', 'Education']] = scale.fit_transform(
    X_train_scale.loc[:, ['Age', 'Education']])
X_test_scale.loc[:, ['Age', 'Education']] = scale.transform(
    X_test_scale.loc[:, ['Age', 'Education']])

# %% [markdown]
# ### Logistic Regression

# %%
grid_log = {'C': [0.1, 1, 10],
            'penalty': ['l1', 'l2']}

gs_log = run_gridsearch_scaled(LogisticRegression, grid_log,
                               X_train_scale, X_test_scale,
                               y_train, y_test, random_state=220)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best params: {'C': 1, 'penalty': 'l1'}
# Train score: 0.712
# Test score: 0.694
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    0.1s finished

# %% [markdown]
# ### Random Forest

# %%
grid_forest = {'n_estimators': [800, 1200],
               'max_depth': [15, 25, 30],
               'min_samples_split': [2, 5],
               'min_samples_leaf': [1, 2],
               'max_features': ['log2']}

gs_forest = run_gridsearch(RandomForestClassifier, grid_forest,
                           X_train, X_test, y_train,
                           y_test, random_state=220)

pickle.dump(gs_forest, open('models/nicotine.sav', 'wb'))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  2.6min finished
# Best params: {'max_depth': 25, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
# Train score: 0.787
# Test score: 0.802

# %% [markdown]
# ### LightGBM

# %%
grid_lgb = {'learning_rate': [0.05, 0.1],
            'max_depth': [15, 17, 25],
            'min_child_weight': [1, 3],
            'subsample': [0.1, 0.3]}

gs_lgb = run_gridsearch(lgb.LGBMClassifier, grid_lgb,
                        X_train, X_test, y_train,
                        y_test, random_state=220)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.5s finished
# Best params: {'learning_rate': 0.1, 'max_depth': 25, 'min_child_weight': 1, 'subsample': 0.1}
# Train score: 0.788
# Test score: 0.785

# %% [markdown]
# ### KNN

# %%
grid_knn = {'n_neighbors': [2, 4, 8]}

gs_knn = run_gridsearch_scaled(KNeighborsClassifier, grid_knn,
                               X_train_scale, X_test_scale,
                               y_train, y_test)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best params: {'n_neighbors': 2}
# Train score: 0.724
# Test score: 0.696
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    0.1s finished

# %% [markdown]
# ### SVM

# %%
grid_svm = {'C': [0.001, 10, 1000],
            'class_weight': ['balanced', None],
            'kernel': ['linear', 'rbf']}

gs_svm = run_gridsearch_scaled('SVM', grid_svm,
                               X_train_scale, X_test_scale,
                               y_train, y_test, random_state=220)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  7.4min finished
# Best params: {'C': 1000, 'class_weight': 'balanced', 'kernel': 'rbf'}
# Train score: 0.754
# Test score: 0.737

# %% [markdown]
# ## Findings

# %% [markdown]
# ### ROC Curve
#
# We used Receiver Operating Characteristic (ROC) curves and the Area Under the Curve (AUC) scores to compare which classification method performed the best. The ROC curve shows the ratio of True Positive and False Positive rates. The perfect model (red dotted line) would show an AUC of 1 and a ROC curve that looks like an upside-down 'L', because the perfect model would show 100% True Positives. The black dotted line shows the ROC curve of a random guess.

# %%
models = [gs_forest, gs_lgb, gs_log, gs_knn, gs_svm]

model_names = ['RandomForest', 'LightGBM',
               'Logistic Regression', 'KNN', 'SVM']

plot_roc_curve(models, model_names, X_test, y_test, 'Nicotine', X_test_scale)

# %% [markdown]
# ### Interpreting Random Forest Results
#
# I chose to focus on the Random Forest model to analyze the accuracy of predictions and which features are most important in predicting nicotine users.

# %%
pickle.dump(gs_forest, open('models/nicotine.sav', 'wb'))

# %%
gs_forest = pickle.load(open('models/nicotine.sav', 'rb'))

# %% [markdown]
# #### Confusion Matrix
#
# The confusion matrix below shows the percent accuracy of predictions. The Random Forest model was 80.2% accurate in predicting whether a person was a user (41%) or a nonuser (39%).

# %%
plot_confusion_matrix(y_test, X_test, gs_forest, 'Nicotine')
plt.savefig('img/nicotine_matrix.png', bbox_inches='tight');

# %% [markdown]
# #### Important Features in Predicting Nicotine Users

# %%
plot_feat_imp(gs_forest, X_train, 'Nicotine')

# %% [markdown]
# ## Conclusion
#
# Based on the 5 classification models, their demographics (age, gender, and education level) and their personalities had accuracy levels of 69-80% in predicting nicotine users. Sensation-seeking and openness to experience were the 2 most influential in predicting nicotine consumption.
